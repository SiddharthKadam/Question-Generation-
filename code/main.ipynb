# %% [markdown]
# # NER

# %%
from named_entity_recognition import NER

context = 'The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.'
ner = NER()
res_sentence_disp,res_sentence_arr=ner.get_ner_context_pivot_ans(context=context)

# %%
res_sentence_disp

# %%
res_sentence_arr

# %% [markdown]
# # POS

# %%
from part_of_speech import POS

context = 'The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.'
pos = POS()
res_sentence_disp,res_sentence_arr=pos.get_pos_context_pivot_ans(context=context)

# %%
res_sentence_disp

# %%
res_sentence_arr

# %% [markdown]
# # GLOVE

# %%
from glove_embeddings import GLOVE_EMBEDDINGS

context = 'The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.'
ner = NER()
res_sentence_disp,res_sentence_arr=ner.get_ner_context_pivot_ans(context=context)


# update this path to yours 
GLOVE_FILE_PATH = "data\glove.6B.300d.txt\glove.6B.300d.txt"
glove =GLOVE_EMBEDDINGS(GLOVE_FILE_PATH)

# %%
for sentence in res_sentence_arr:
    tagged_sentence = sentence["tagged_sentence"]
    context_words_emmbedings,context_tags_emmbedings=glove.get_glove_emmbedding_way_1(tagged_sentence)
    print(len(context_words_emmbedings[0]))
    print(context_tags_emmbedings)
    break

# %%
for sentence in res_sentence_arr:
    tagged_sentence = sentence["tagged_sentence"]
    context_words_emmbedings,context_tags_emmbedings=glove.get_glove_emmbedding_way_2(tagged_sentence)
    print(len(context_words_emmbedings[0]))
    print(context_tags_emmbedings)
    break

# %%
for sentence in res_sentence_arr:
    tagged_sentence = sentence["tagged_sentence"]
    context_words_emmbedings,context_tags_emmbedings=glove.get_glove_emmbedding_way_3(tagged_sentence)
    print(len(context_words_emmbedings[0]))
    print(context_tags_emmbedings)
    break

# %%
glove.dynamic_emb_dict.keys()

# %%
glove.create_dynamic_dict_file()

# %% [markdown]
# # Evaluation (Meteor Score)

# %%
import pickle
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

with open('data\que_ans_data.pkl', 'rb') as file:
    data = pickle.load(file)
data=data.head(50)
data=data[["context_id","question"]]
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\q'
# <>:5: SyntaxWarning: invalid escape sequence '\q'
# C:\Users\siddh\AppData\Local\Temp\ipykernel_17644\3849865265.py:5: SyntaxWarning: invalid escape sequence '\q'
#   with open('data\que_ans_data.pkl', 'rb') as file:

# %%
def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    words = word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

data["gen_question"] =  data["question"].apply(remove_stopwords)

# %%
from evaluation import Meteor

meteor =Meteor()
meteor.evaluate(data)
# Out:
# c:\Users\siddh\Documents\DA-IICT\PROJECT\Information_Reterival\PARA_QG\python-code\evaluation.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.2720905172413793' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[i,"meteor_score"] =  self.get_meteor_score(row.gen_question,row.question)
#     context_id                                           question  \
# 0            0               In what country is Normandy located?
# 1            0                 When were the Normans in Normandy?
# 2            0      From which countries did the Norse originate?
# 3            0                          Who was the Norse leader?
# 4            0  What century did the Normans first gain their ...
# 5            0  Who gave their name to Normandy in the 1000's ...
# 6            0                        What is France a region of?
# ...
